# %%
import pandas as pd

# %%
df_transactions = pd.read_csv('../data/raw/creditcard.csv')  
df_ip = pd.read_csv('../data/raw/IpAddress_to_Country.csv')

# %%
print(df_ip.shape)
print(df_ip.columns)
# Out:
# (138846, 4)
# Index(['lower_bound_ip_address', 'upper_bound_ip_address', 'country',
#        'ip_int'],
#       dtype='object')

# %%
df_ip.head()
# Out:
#    lower_bound_ip_address  upper_bound_ip_address    country
# 0              16777216.0                16777471  Australia
# 1              16777472.0                16777727      China
# 2              16777728.0                16778239      China
# 3              16778240.0                16779263  Australia
# 4              16779264.0                16781311      China

# %%
# number of country
NUMBER_OF_COUNTRIES =df_ip['country'].nunique()
print(f"Number of unique countries: {NUMBER_OF_COUNTRIES}")
# MOST FREQUENT COUNTRIES TOP 10
print(df_ip['country'].value_counts().head(15))
# Out:
# Number of unique countries: 235
# country
# United States         46868
# Canada                 6989
# Russian Federation     6739
# Australia              6316
# Germany                5999
# United Kingdom         5401
# Brazil                 4885
# China                  3725
# Poland                 3042
# Japan                  3005
# Ukraine                2903
# France                 2892
# Netherlands            2509
# Switzerland            1821
# Italy                  1711
# Name: count, dtype: int64

# %%
# The 'upper_bound_ip_address' column is already in integer format, so we can just copy it
df_ip['ip_int'] = df_ip['upper_bound_ip_address']

# Merge Fraud_Data.csv with IpAddress_to_Country.csv
df_fraud = df_transactions.merge(df_ip, left_on='upper_bound_ip_address', right_on='upper_bound_ip_address', how='left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14424\753022302.py in ?()
#       1 # The 'upper_bound_ip_address' column is already in integer format, so we can just copy it
#       2 df_ip['ip_int'] = df_ip['upper_bound_ip_address']
#       3
#       4 # Merge Fraud_Data.csv with IpAddress_to_Country.csv
# ----> 5 df_fraud = df_transactions.merge(df_ip, left_on='upper_bound_ip_address', right_on='upper_bound_ip_address', how='left')
#
# c:\Users\nebiy\OneDrive\Documents\code\kiam\week-8\venv\Lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10835         validate: MergeValidate | None = None,
#   10836     ) -> DataFrame:
#   10837         from pandas.core.reshape.merge import merge
#   10838
# > 10839         return merge(
# ...

# %%
df_transactions.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df_transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...
